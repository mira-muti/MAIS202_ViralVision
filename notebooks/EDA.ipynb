# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# **Owner:** Backend Pod (Person 1 or 2)
#
# **Purpose:**
# - Explore the extracted features from videos
# - Visualize distributions of audio and visual features
# - Identify correlations between features and virality
# - Detect outliers and missing values
# - Inform feature engineering decisions
#
# **Sections to implement:**
# 1. Load the dataset
# 2. Basic statistics and info
# 3. Feature distributions (histograms, boxplots)
# 4. Correlation analysis
# 5. Class balance (viral vs. not viral)
# 6. Feature importance exploration
# 7. Visualizations and insights

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load the Dataset

# %%
# TODO: Load data/final_dataset.csv
# df = pd.read_csv('../data/final_dataset.csv')
# df.head()

# %% [markdown]
# ## 2. Basic Statistics

# %%
# TODO: Show dataset info, shape, dtypes, missing values
# df.info()
# df.describe()

# %% [markdown]
# ## 3. Feature Distributions

# %%
# TODO: Plot histograms for all numeric features
# df.hist(figsize=(15, 10), bins=30)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 4. Correlation Analysis

# %%
# TODO: Create correlation heatmap
# plt.figure(figsize=(12, 10))
# sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
# plt.title('Feature Correlation Heatmap')
# plt.show()

# %% [markdown]
# ## 5. Class Balance

# %%
# TODO: Check distribution of target variable (viral vs. not viral)
# df['is_viral'].value_counts().plot(kind='bar')
# plt.title('Class Distribution')
# plt.xlabel('Virality')
# plt.ylabel('Count')
# plt.show()

# %% [markdown]
# ## 6. Insights and Next Steps
#
# **TODO: Document key findings:**
# - Which features are most correlated with virality?
# - Are there any outliers to handle?
# - Is the dataset balanced?
# - What preprocessing steps are needed?
