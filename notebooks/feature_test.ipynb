# %% [markdown]
# # Feature Extraction Testing
#
# **Owner:** Backend Pod (Person 1)
#
# **Purpose:**
# - Test audio and visual feature extraction functions
# - Debug issues with individual videos
# - Verify feature extraction pipeline works correctly
# - Quick experimentation with different feature extraction methods
#
# **Use this notebook to:**
# - Test `extract_audio_features()` on sample videos
# - Test `extract_visual_features()` on sample videos
# - Visualize extracted features
# - Identify corrupted or problematic video files

# %%
# Import libraries
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# from preprocess import extract_audio_features, extract_visual_features

# %% [markdown]
# ## 1. Test Audio Feature Extraction

# %%
# TODO: Test extract_audio_features on a sample video
# sample_video = '../data/raw/sample_video.mp4'
# audio_features = extract_audio_features(sample_video)
# print(audio_features)

# %% [markdown]
# ## 2. Test Visual Feature Extraction

# %%
# TODO: Test extract_visual_features on a sample video
# visual_features = extract_visual_features(sample_video)
# print(visual_features)

# %% [markdown]
# ## 3. Visualize Features

# %%
# TODO: Create visualizations of extracted features
# For example:
# - Plot waveform and spectrogram for audio
# - Show sample frames and color histograms for video

# %% [markdown]
# ## 4. Test on Multiple Videos

# %%
# TODO: Test feature extraction on multiple videos
# Identify any videos that cause errors
# Measure processing time per video

# %% [markdown]
# ## 5. Debug and Refine

# %%
# TODO: Use this section to debug any issues
# Test different librosa/cv2 parameters
# Experiment with alternative feature extraction methods
